# %%
numbers=[10,20,30,40,50]
print(numbers[0])
print(numbers[-1])
print(numbers[1:4])
numbers.append(60)
print(numbers[5])
print(numbers)
print(len(numbers))
# Out:
# 10
# 50
# [20, 30, 40]
# 60
# [10, 20, 30, 40, 50, 60]
# 6

# %%
type(numbers)
# Out:
# list

# %%
numbers[2]=40
print(numbers)
# Out:
# [10, 20, 40, 40, 50, 60]

# %%
numbers.count(40)
# Out:
# 2

# %%
numbers.index(50)
# Out:
# 4

# %%
numbers=[10,20,40,40,50,60]
numbers.remove(10)
print(numbers)
# Out:
# [20, 40, 40, 50, 60]

# %%
numbers=[10,20,40,40,50,60]
numbers.insert(4,15)
print(numbers)
# Out:
# [10, 20, 40, 40, 15, 50, 60]

# %%
numbers=[10,20,40,40,50,60]
numbers.pop(4)
print(numbers)
# Out:
# [10, 20, 40, 40, 60]

# %%
numbers=[10,20,40,40,50,60]
numbers.extend([33,44,55])
print(numbers)
# Out:
# [10, 20, 40, 40, 50, 60, 33, 44, 55]

# %%
numbers.append([11,22])
print(numbers)
# Out:
# [10, 20, 40, 40, 50, 60, 33, 44, 55, [11, 22], [11, 22]]

# %%
numbers[9]
# Out:
# [11, 22]

# %%
numbers[9][1]
# Out:
# 22

# %%
numbers[10][0]
# Out:
# 11

# %%
numbers=[10,20,42,40,53,60]
numbers.sort()
print(numbers)
# Out:
# [10, 20, 40, 42, 53, 60]

# %%
example=[6,9,1,4,2,3]
example.sort()
print(example)
# Out:
# [1, 2, 3, 4, 6, 9]

# %%
example.reverse()
print(example)
# Out:
# [1, 2, 3, 4, 6, 9]

# %%
new=example.copy()
new
# Out:
# [1, 2, 3, 4, 6, 9]

# %%
numbers.clear()
numbers
# Out:
# []

# %%
numbers=(10,20,30,20)
type(numbers)
# Out:
# tuple

# %%
numbers.count(20)
# Out:
# 2

# %%
numbers.index(10)
# Out:
# 0

# %%
numbers[1:3]
# Out:
# (20, 30)

# %%
print(len(numbers))
# Out:
# 4

# %%
len(numbers)
# Out:
# 4

# %%
sorted(numbers)
# Out:
# [10, 20, 20, 30]

# %% [markdown]
# set

# %%
digits={10,20,30,20,}
print(digits)
# Out:
# {10, 20, 30}

# %%
digits.add(40)
digits
# Out:
# {10, 20, 30, 40}

# %%
type(digits)
# Out:
# set

# %%
digits.remove(20)
digits
# Out:
# {30}

# %%
digits.discard(10)
digits
# Out:
# {20, 30}

# %%
print(digits.discard(23))
# Out:
# None

# %%
len(digits)
# Out:
# 1

# %%
A={1,2,3,4,}
B={6,8,7,9,1}
print(A|B)
# Out:
# {1, 2, 3, 4, 6, 7, 8, 9}

# %%
print(A-B)
# Out:
# {2, 3, 4}

# %%
print(A^B)
# Out:
# {2, 3, 4, 6, 7, 8, 9}

# %%
print(A & B)
# Out:
# {1}

# %%
A={1,2,3,4,5,6,7}
B={2,4,6,5,7,8,9}
print(A|B)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
print(A - B)
# Out:
# {1, 3}

# %%
print(A&B)
# Out:
# {2, 4, 5, 6, 7}

# %%
print(A^B)
# Out:
# {1, 3, 8, 9}

# %% [markdown]
# Dictionary

# %%
student={"name":"Deepa","age":20,"course":"ML"}
print(student["name"])
# Out:
# Deepa

# %%
student["city"]="Gadag"
student
# Out:
# {'name': 'Deepa', 'age': 20, 'course': 'ML', 'city': 'Gadag'}

# %%
student.update({"age":21})
student
# Out:
# {'name': 'Deepa', 'age': 21, 'course': 'ML', 'city': 'Gadag'}
