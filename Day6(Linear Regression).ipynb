# %%
# Simple Linear Regression
#import Libraries
import numpy as py # Number calc
import pandas as pd # Using for Data table
import matplotlib.pyplot as plt # Data Visualization
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
# Create Datasets
data={'study_hour':[1,2,3,4,5],'marks':[35,40,45,50,55]}
df=pd.DataFrame(data)

# 3) find out input and output variables
X=df[['study_hour']]
Y=df['marks']

# 4) Train-Test model
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)
model=LinearRegression()
model.fit(X,Y)
prediction=model.predict([[7]])
plt.scatter(x,y)
plt.plot(x,model.predict(x),color='red')
plt.title('Simplr Linear Regression')
plt.xlabel('study_hour')
plt.ylabel('marks')
plt.grid()
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /tmp/ipykernel_3207/624796790.py:28: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
