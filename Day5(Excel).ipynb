# %%
import pandas as pd
data=pd.read_excel("/content/Excel.xlsl.xlsx")
data
# Out:
#     Unnamed: 0 Student_ID     Name    Age     Gender Course  Marks       City  \
# 0            0       S201    Rahul   20.0       Male    BCA   85.0  Bengaluru
# 1            1       S202    Priya    NaN     Female    BBA   78.0    Chennai
# 2            2       S203    Arjun   21.0       Male    BCA   92.0  Hyderabad
# 3            3       S204    Sneha   19.0     Female    MCA   88.0     Mysuru
# 4            4       S205    Kiran  150.0       Male    BBA   65.0  Bengaluru
# 5            5       S206   Anjali   22.0     Female    BCA  -45.0    Chennai
# 6            6       S207     Ravi   21.0       Male    MCA   95.0      Delhi
# 7            7       S208      NaN   20.0     Female    BCA   72.0  Hyderabad
# 8            8       S209    Manju  -19.0     Female    BBA   80.0  Bengaluru
# 9            9       S210   Suresh   22.0       Male    MCA   89.0    Chennai
# 10          10       S201    Rahul   20.0       Male    BCA   85.0  Bengaluru
# ...

# %%
data.isnull()
# Out:
#     Unnamed: 0  Student_ID   Name    Age  Gender  Course  Marks   City  \
# 0        False       False  False  False   False   False  False  False
# 1        False       False  False   True   False   False  False  False
# 2        False       False  False  False   False   False  False  False
# 3        False       False  False  False   False   False  False  False
# 4        False       False  False  False   False   False  False  False
# 5        False       False  False  False   False   False  False  False
# 6        False       False  False  False   False   False  False  False
# 7        False       False   True  False   False   False  False  False
# 8        False       False  False  False   False   False  False  False
# 9        False       False  False  False   False   False  False  False
# 10       False       False  False  False   False   False  False  False
# 11       False       False  False  False   False    True  False  False
# ...

# %%
import numpy as np
data.loc[data['Age']>90,'Age']=np.nan
data
# Out:
#     Unnamed: 0 Student_ID     Name   Age     Gender Course  Marks       City  \
# 0            0       S201    Rahul  20.0       Male    BCA   85.0  Bengaluru
# 1            1       S202    Priya   NaN     Female    BBA   78.0    Chennai
# 2            2       S203    Arjun  21.0       Male    BCA   92.0  Hyderabad
# 3            3       S204    Sneha  19.0     Female    MCA   88.0     Mysuru
# 4            4       S205    Kiran   NaN       Male    BBA   65.0  Bengaluru
# 5            5       S206   Anjali  22.0     Female    BCA  -45.0    Chennai
# 6            6       S207     Ravi  21.0       Male    MCA   95.0      Delhi
# 7            7       S208      NaN  20.0     Female    BCA   72.0  Hyderabad
# 8            8       S209    Manju -19.0     Female    BBA   80.0  Bengaluru
# 9            9       S210   Suresh  22.0       Male    MCA   89.0    Chennai
# 10          10       S201    Rahul  20.0       Male    BCA   85.0  Bengaluru
# ...

# %%
data['Age']=data['Age'].fillna(data['Age'].mean())
data
# Out:
#     Unnamed: 0 Student_ID     Name        Age     Gender Course  Marks  \
# 0            0       S201    Rahul  20.000000       Male    BCA   85.0
# 1            1       S202    Priya  17.846154     Female    BBA   78.0
# 2            2       S203    Arjun  21.000000       Male    BCA   92.0
# 3            3       S204    Sneha  19.000000     Female    MCA   88.0
# 4            4       S205    Kiran  17.846154       Male    BBA   65.0
# 5            5       S206   Anjali  22.000000     Female    BCA  -45.0
# 6            6       S207     Ravi  21.000000       Male    MCA   95.0
# 7            7       S208      NaN  20.000000     Female    BCA   72.0
# 8            8       S209    Manju -19.000000     Female    BBA   80.0
# 9            9       S210   Suresh  22.000000       Male    MCA   89.0
# 10          10       S201    Rahul  20.000000       Male    BCA   85.0
# 11          11       S212    Divya  21.000000     Female    NaN   76.0
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0          int64
# Student_ID         object
# Name               object
# Age               float64
# Gender             object
# Course             object
# Marks             float64
# City               object
# Admission_Date     object
# dtype: object

# %%
data['Age']=data['Age'].astype(int)
data
# Out:
#     Unnamed: 0 Student_ID     Name  Age     Gender Course  Marks       City  \
# 0            0       S201    Rahul   20       Male    BCA   85.0  Bengaluru
# 1            1       S202    Priya   17     Female    BBA   78.0    Chennai
# 2            2       S203    Arjun   21       Male    BCA   92.0  Hyderabad
# 3            3       S204    Sneha   19     Female    MCA   88.0     Mysuru
# 4            4       S205    Kiran   17       Male    BBA   65.0  Bengaluru
# 5            5       S206   Anjali   22     Female    BCA  -45.0    Chennai
# 6            6       S207     Ravi   21       Male    MCA   95.0      Delhi
# 7            7       S208      NaN   20     Female    BCA   72.0  Hyderabad
# 8            8       S209    Manju  -19     Female    BBA   80.0  Bengaluru
# 9            9       S210   Suresh   22       Male    MCA   89.0    Chennai
# 10          10       S201    Rahul   20       Male    BCA   85.0  Bengaluru
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0          int64
# Student_ID         object
# Name               object
# Age                 int64
# Gender             object
# Course             object
# Marks             float64
# City               object
# Admission_Date     object
# dtype: object

# %%
data['Gender']=data['Gender'].replace({"M":"Male","F":"Female"})
data
# Out:
#     Unnamed: 0 Student_ID     Name  Age     Gender Course  Marks       City  \
# 0            0       S201    Rahul   20       Male    BCA   85.0  Bengaluru
# 1            1       S202    Priya   17     Female    BBA   78.0    Chennai
# 2            2       S203    Arjun   21       Male    BCA   92.0  Hyderabad
# 3            3       S204    Sneha   19     Female    MCA   88.0     Mysuru
# 4            4       S205    Kiran   17       Male    BBA   65.0  Bengaluru
# 5            5       S206   Anjali   22     Female    BCA  -45.0    Chennai
# 6            6       S207     Ravi   21       Male    MCA   95.0      Delhi
# 7            7       S208      NaN   20     Female    BCA   72.0  Hyderabad
# 8            8       S209    Manju  -19     Female    BBA   80.0  Bengaluru
# 9            9       S210   Suresh   22       Male    MCA   89.0    Chennai
# 10          10       S201    Rahul   20       Male    BCA   85.0  Bengaluru
# ...

# %%
data=pd.get_dummies(data,columns=['Gender'],dtype=int)
data
# Out:
#     Unnamed: 0 Student_ID     Name  Age Course  Marks       City  \
# 0            0       S201    Rahul   20    BCA   85.0  Bengaluru
# 1            1       S202    Priya   17    BBA   78.0    Chennai
# 2            2       S203    Arjun   21    BCA   92.0  Hyderabad
# 3            3       S204    Sneha   19    MCA   88.0     Mysuru
# 4            4       S205    Kiran   17    BBA   65.0  Bengaluru
# 5            5       S206   Anjali   22    BCA  -45.0    Chennai
# 6            6       S207     Ravi   21    MCA   95.0      Delhi
# 7            7       S208      NaN   20    BCA   72.0  Hyderabad
# 8            8       S209    Manju  -19    BBA   80.0  Bengaluru
# 9            9       S210   Suresh   22    MCA   89.0    Chennai
# 10          10       S201    Rahul   20    BCA   85.0  Bengaluru
# 11          11       S212    Divya   21    NaN   76.0     Mysuru
# 12          12       S213   Naveen   22    BCA    NaN  Hyderabad
# ...

# %%
import pandas as pd
data=pd.read_excel("/content/Student.xlsx")
data
# Out:
#    Student_ID     Name    Age     Gender Course  Marks         City  \
# 0        S201    Rahul   20.0          M    BCA   85.0    Bengaluru
# 1        S202    Priya    NaN     Female    BBA   78.0      Chennai
# 2        S203    Arjun   21.0       Male    BCA   92.0    Hyderabad
# 3        S204    Sneha   19.0          F    MCA   88.0       Mysuru
# 4        S205    Kiran  150.0       Male    BBA   65.0    Bengaluru
# 5        S206   Anjali   22.0     Female    BCA  -45.0      Chennai
# 6         NaN     Ravi   21.0          M    MCA   95.0        Delhi
# 7        S208      NaN   20.0     Female    BCA   72.0    Hyderabad
# 8        S209    Manju  -19.0          F    BBA   80.0    Bengaluru
# 9        S210   Suresh   22.0       Male    MCA   89.0      Chennai
# 10       S201    Rahul   20.0          M    BCA   85.0    Bengaluru
# 11       S212    Divya   21.0     Female    NaN   76.0       Mysuru
# 12       S213   Naveen   22.0       Male    BCA    NaN    Hyderabad
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student_ID      14 non-null     object
#  1   Name            14 non-null     object
#  2   Age             14 non-null     float64
#  3   Gender          15 non-null     object
#  4   Course          14 non-null     object
#  5   Marks           14 non-null     float64
#  6   City            14 non-null     object
#  7   Admission_Date  15 non-null     object
# dtypes: float64(2), object(6)
# memory usage: 1.1+ KB

# %%
data.dtypes
# Out:
# Student_ID         object
# Name               object
# Age               float64
# Gender             object
# Course             object
# Marks             float64
# City               object
# Admission_Date     object
# dtype: object

# %%
data.head()
# Out:
#   Student_ID   Name    Age  Gender Course  Marks       City  \
# 0       S201  Rahul   20.0       M    BCA   85.0  Bengaluru
# 1       S202  Priya    NaN  Female    BBA   78.0    Chennai
# 2       S203  Arjun   21.0    Male    BCA   92.0  Hyderabad
# 3       S204  Sneha   19.0       F    MCA   88.0     Mysuru
# 4       S205  Kiran  150.0    Male    BBA   65.0  Bengaluru
#
#         Admission_Date
# 0  2023-12-06 00:00:00
# 1           15-07-2023
# 2  2023-10-08 00:00:00
# 3           20-06-2023
# 4  2023-10-07 00:00:00

# %%
data.tail()
# Out:
#    Student_ID     Name   Age     Gender Course  Marks         City  \
# 10       S201    Rahul  20.0          M    BCA   85.0    Bengaluru
# 11       S212    Divya  21.0     Female    NaN   76.0       Mysuru
# 12       S213   Naveen  22.0       Male    BCA    NaN    Hyderabad
# 13       S214    Pooja  20.0     Female    BBA   68.0          NaN
# 14       S215   Mahesh  23.0       Male    MCA  105.0    Bengaluru
#
#          Admission_Date
# 10  2023-12-06 00:00:00
# 11           18-07-2023
# 12           25-08-2023
# 13  2023-12-07 00:00:00
# 14           30-06-2023

# %%
data.isnull()
# Out:
#     Student_ID   Name    Age  Gender  Course  Marks   City  Admission_Date
# 0        False  False  False   False   False  False  False           False
# 1        False  False   True   False   False  False  False           False
# 2        False  False  False   False   False  False  False           False
# 3        False  False  False   False   False  False  False           False
# 4        False  False  False   False   False  False  False           False
# 5        False  False  False   False   False  False  False           False
# 6         True  False  False   False   False  False  False           False
# 7        False   True  False   False   False  False  False           False
# 8        False  False  False   False   False  False  False           False
# 9        False  False  False   False   False  False  False           False
# 10       False  False  False   False   False  False  False           False
# ...

# %%
data.isnull().sum()
# Out:
# Student_ID        1
# Name              1
# Age               1
# Gender            0
# Course            1
# Marks             1
# City              1
# Admission_Date    0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# np.int64(6)

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# dtype: bool

# %%
data.duplicated().sum()
# Out:
# np.int64(1)

# %%
data.drop_duplicates()
# Out:
#    Student_ID     Name    Age     Gender Course  Marks         City  \
# 0        S201    Rahul   20.0          M    BCA   85.0    Bengaluru
# 1        S202    Priya    NaN     Female    BBA   78.0      Chennai
# 2        S203    Arjun   21.0       Male    BCA   92.0    Hyderabad
# 3        S204    Sneha   19.0          F    MCA   88.0       Mysuru
# 4        S205    Kiran  150.0       Male    BBA   65.0    Bengaluru
# 5        S206   Anjali   22.0     Female    BCA  -45.0      Chennai
# 6         NaN     Ravi   21.0          M    MCA   95.0        Delhi
# 7        S208      NaN   20.0     Female    BCA   72.0    Hyderabad
# 8        S209    Manju  -19.0          F    BBA   80.0    Bengaluru
# 9        S210   Suresh   22.0       Male    MCA   89.0      Chennai
# 11       S212    Divya   21.0     Female    NaN   76.0       Mysuru
# 12       S213   Naveen   22.0       Male    BCA    NaN    Hyderabad
# 13       S214    Pooja   20.0     Female    BBA   68.0          NaN
# ...

# %%
data['Student_ID']=data['Student_ID'].fillna('S207')
data
# Out:
#    Student_ID     Name   Age     Gender Course  Marks       City
# 0        S201    Rahul    20       Male    BCA   85.0  Bengaluru
# 1        S202    Priya  <NA>     Female    BBA   78.0    Chennai
# 2        S203    Arjun    21       Male    BCA   92.0  Hyderabad
# 3        S204    Sneha    19     Female    MCA   88.0     Mysuru
# 4        S205    Kiran   150       Male    BBA   65.0  Bengaluru
# 5        S206   Anjali    22     Female    BCA  -45.0    Chennai
# 6        S207     Ravi    21       Male    MCA   95.0      Delhi
# 7        S208      NaN    20     Female    BCA   72.0  Hyderabad
# 8        S209    Manju   -19     Female    BBA   80.0  Bengaluru
# 9        S210   Suresh    22       Male    MCA   89.0    Chennai
# 10       S201    Rahul    20       Male    BCA   85.0  Bengaluru
# 11       S212    Divya    21     Female    NaN   76.0     Mysuru
# 12       S213   Naveen    22       Male    BCA    NaN  Hyderabad
# ...

# %%
data.loc[data['Marks']>100,'Marks']=np.nan
data
# Out:
#    Student_ID     Name   Age     Gender Course  Marks       City
# 0        S201    Rahul    20       Male    BCA   85.0  Bengaluru
# 1        S202    Priya  <NA>     Female    BBA   78.0    Chennai
# 2        S203    Arjun    21       Male    BCA   92.0  Hyderabad
# 3        S204    Sneha    19     Female    MCA   88.0     Mysuru
# 4        S205    Kiran   150       Male    BBA   65.0  Bengaluru
# 5        S206   Anjali    22     Female    BCA  -45.0    Chennai
# 6        S207     Ravi    21       Male    MCA   95.0      Delhi
# 7        S208      NaN    20     Female    BCA   72.0  Hyderabad
# 8        S209    Manju   -19     Female    BBA   80.0  Bengaluru
# 9        S210   Suresh    22       Male    MCA   89.0    Chennai
# 10       S201    Rahul    20       Male    BCA   85.0  Bengaluru
# 11       S212    Divya    21     Female    NaN   76.0     Mysuru
# 12       S213   Naveen    22       Male    BCA    NaN  Hyderabad
# ...

# %%
data['Gender']=data['Gender'].replace({"M":"Male","F":"Female"})
data
# Out:
#    Student_ID     Name    Age     Gender Course  Marks         City  \
# 0        S201    Rahul   20.0       Male    BCA   85.0    Bengaluru
# 1        S202    Priya    NaN     Female    BBA   78.0      Chennai
# 2        S203    Arjun   21.0       Male    BCA   92.0    Hyderabad
# 3        S204    Sneha   19.0     Female    MCA   88.0       Mysuru
# 4        S205    Kiran  150.0       Male    BBA   65.0    Bengaluru
# 5        S206   Anjali   22.0     Female    BCA  -45.0      Chennai
# 6        S207     Ravi   21.0       Male    MCA   95.0        Delhi
# 7        S208      NaN   20.0     Female    BCA   72.0    Hyderabad
# 8        S209    Manju  -19.0     Female    BBA   80.0    Bengaluru
# 9        S210   Suresh   22.0       Male    MCA   89.0      Chennai
# 10       S201    Rahul   20.0       Male    BCA   85.0    Bengaluru
# 11       S212    Divya   21.0     Female    NaN   76.0       Mysuru
# 12       S213   Naveen   22.0       Male    BCA    NaN    Hyderabad
# ...

# %%
data['Age']=data['Age'].astype('Int64')
data
# Out:
#    Student_ID     Name   Age     Gender Course  Marks         City  \
# 0        S201    Rahul    20       Male    BCA   85.0    Bengaluru
# 1        S202    Priya  <NA>     Female    BBA   78.0      Chennai
# 2        S203    Arjun    21       Male    BCA   92.0    Hyderabad
# 3        S204    Sneha    19     Female    MCA   88.0       Mysuru
# 4        S205    Kiran   150       Male    BBA   65.0    Bengaluru
# 5        S206   Anjali    22     Female    BCA  -45.0      Chennai
# 6        S207     Ravi    21       Male    MCA   95.0        Delhi
# 7        S208      NaN    20     Female    BCA   72.0    Hyderabad
# 8        S209    Manju   -19     Female    BBA   80.0    Bengaluru
# 9        S210   Suresh    22       Male    MCA   89.0      Chennai
# 10       S201    Rahul    20       Male    BCA   85.0    Bengaluru
# 11       S212    Divya    21     Female    NaN   76.0       Mysuru
# 12       S213   Naveen    22       Male    BCA    NaN    Hyderabad
# ...

# %%
data.describe()
# Out:
#              Age      Marks
# count       14.0  13.000000
# mean   27.285714  71.384615
# std    36.902009  36.144475
# min        -19.0 -45.000000
# 25%         20.0  72.000000
# 50%         21.0  80.000000
# 75%         22.0  88.000000
# max        150.0  95.000000

# %%
data['City']=data['City'].str.strip()
data
# Out:
#    Student_ID     Name   Age     Gender Course  Marks       City  \
# 0        S201    Rahul    20       Male    BCA   85.0  Bengaluru
# 1        S202    Priya  <NA>     Female    BBA   78.0    Chennai
# 2        S203    Arjun    21       Male    BCA   92.0  Hyderabad
# 3        S204    Sneha    19     Female    MCA   88.0     Mysuru
# 4        S205    Kiran   150       Male    BBA   65.0  Bengaluru
# 5        S206   Anjali    22     Female    BCA  -45.0    Chennai
# 6        S207     Ravi    21       Male    MCA   95.0      Delhi
# 7        S208      NaN    20     Female    BCA   72.0  Hyderabad
# 8        S209    Manju   -19     Female    BBA   80.0  Bengaluru
# 9        S210   Suresh    22       Male    MCA   89.0    Chennai
# 10       S201    Rahul    20       Male    BCA   85.0  Bengaluru
# 11       S212    Divya    21     Female    NaN   76.0     Mysuru
# 12       S213   Naveen    22       Male    BCA    NaN  Hyderabad
# ...

# %%
data.shape
# Out:
# (15, 8)

# %%
data.columns
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Gender', 'Course', 'Marks', 'City',
#        'Admission_Date'],
#       dtype='object')

# %%
data.to_csv()
# Out:
# ',Student_ID,Name,Age,Gender,Course,Marks,City,Admission_Date\n0,S201,Rahul,20,Male,BCA,85.0,Bengaluru,2023-12-06 00:00:00\n1,S202,Priya,,Female,BBA,78.0,Chennai,15-07-2023\n2,S203,Arjun,21,Male,BCA,92.0,Hyderabad,2023-10-08 00:00:00\n3,S204,Sneha,19,Female,MCA,88.0,Mysuru,20-06-2023\n4,S205,Kiran,150,Male,BBA,65.0,Bengaluru,2023-10-07 00:00:00\n5,S206,Anjali,22,Female,  BCA,-45.0,Chennai,15-07-2023\n6,S207,Ravi,21,Male,MCA,95.0,Delhi,2023-01-08 00:00:00\n7,S208,,20,Female,BCA,72.0,Hyderabad,22-08-2023\n8,S209,Manju,-19,Female,BBA,80.0,Bengaluru,2023-10-07 00:00:00\n9,S210,Suresh,22,Male,MCA,89.0,Chennai,2023-05-08 00:00:00\n10,S201,Rahul,20,Male,BCA,85.0,Bengaluru,2023-12-06 00:00:00\n11,S212,  Divya,21,Female,,76.0,Mysuru,18-07-2023\n12,S213,Naveen,22,Male,BCA,,Hyderabad,25-08-2023\n13,S214,Pooja,20,   Female,BBA,68.0,,2023-12-07 00:00:00\n14,S215,Mahesh,23,Male,MCA,,Bengaluru,30-06-2023\n'

# %%
data.to_excel("/content/Excel.xlsl.xlsx")
data
# Out:
#    Student_ID     Name   Age     Gender Course  Marks       City  \
# 0        S201    Rahul    20       Male    BCA   85.0  Bengaluru
# 1        S202    Priya  <NA>     Female    BBA   78.0    Chennai
# 2        S203    Arjun    21       Male    BCA   92.0  Hyderabad
# 3        S204    Sneha    19     Female    MCA   88.0     Mysuru
# 4        S205    Kiran   150       Male    BBA   65.0  Bengaluru
# 5        S206   Anjali    22     Female    BCA  -45.0    Chennai
# 6        S207     Ravi    21       Male    MCA   95.0      Delhi
# 7        S208      NaN    20     Female    BCA   72.0  Hyderabad
# 8        S209    Manju   -19     Female    BBA   80.0  Bengaluru
# 9        S210   Suresh    22       Male    MCA   89.0    Chennai
# 10       S201    Rahul    20       Male    BCA   85.0  Bengaluru
# 11       S212    Divya    21     Female    NaN   76.0     Mysuru
# 12       S213   Naveen    22       Male    BCA    NaN  Hyderabad
# ...

# %%
data['Age'].mean()
# Out:
# np.float64(27.285714285714285)

# %%
data['Marks'].mean()
# Out:
# np.float64(71.38461538461539)

# %%
data=data.drop(['Admission_Date'],axis=1)
data
# Out:
#    Student_ID     Name   Age     Gender Course  Marks       City
# 0        S201    Rahul    20       Male    BCA   85.0  Bengaluru
# 1        S202    Priya  <NA>     Female    BBA   78.0    Chennai
# 2        S203    Arjun    21       Male    BCA   92.0  Hyderabad
# 3        S204    Sneha    19     Female    MCA   88.0     Mysuru
# 4        S205    Kiran   150       Male    BBA   65.0  Bengaluru
# 5        S206   Anjali    22     Female    BCA  -45.0    Chennai
# 6        S207     Ravi    21       Male    MCA   95.0      Delhi
# 7        S208      NaN    20     Female    BCA   72.0  Hyderabad
# 8        S209    Manju   -19     Female    BBA   80.0  Bengaluru
# 9        S210   Suresh    22       Male    MCA   89.0    Chennai
# 10       S201    Rahul    20       Male    BCA   85.0  Bengaluru
# 11       S212    Divya    21     Female    NaN   76.0     Mysuru
# 12       S213   Naveen    22       Male    BCA    NaN  Hyderabad
# ...

# %%
data['Age'].max()
# Out:
# np.int64(150)

# %%
data['Marks'].min()
# Out:
# -45.0

# %%
data['Age'].min()
# Out:
# np.int64(-19)

# %%
data['Marks'].max()
# Out:
# 95.0

# %%
data.shape
# Out:
# (15, 7)

# %%
data['Marks'].median()
# Out:
# 80.0

# %%
print(data['Course'].unique())
# Out:
# ['BCA' 'BBA' 'MCA' '  BCA' nan]

# %%
print(data['Course'].value_counts())
# Out:
# Course
# BCA      5
# BBA      4
# MCA      4
#   BCA    1
# Name: count, dtype: int64

# %%
data['Marks'].mode()
# Out:
# 0    85.0
# Name: Marks, dtype: float64

# %%
data.describe()
# Out:
#              Age      Marks
# count       14.0  13.000000
# mean   27.285714  71.384615
# std    36.902009  36.144475
# min        -19.0 -45.000000
# 25%         20.0  72.000000
# 50%         21.0  80.000000
# 75%         22.0  88.000000
# max        150.0  95.000000

# %%
data.interpolate()
# Out:
# /tmp/ipykernel_3591/982976692.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data.interpolate()
#    Student_ID     Name    Age     Gender Course  Marks       City
# 0        S201    Rahul   20.0       Male    BCA   85.0  Bengaluru
# 1        S202    Priya   20.5     Female    BBA   78.0    Chennai
# 2        S203    Arjun   21.0       Male    BCA   92.0  Hyderabad
# 3        S204    Sneha   19.0     Female    MCA   88.0     Mysuru
# 4        S205    Kiran  150.0       Male    BBA   65.0  Bengaluru
# 5        S206   Anjali   22.0     Female    BCA  -45.0    Chennai
# 6        S207     Ravi   21.0       Male    MCA   95.0      Delhi
# 7        S208      NaN   20.0     Female    BCA   72.0  Hyderabad
# 8        S209    Manju  -19.0     Female    BBA   80.0  Bengaluru
# 9        S210   Suresh   22.0       Male    MCA   89.0    Chennai
# ...
