# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# python second program

# %%
print("*"*3);
# Out:
# ***

# %%
print("*\n"*3)
# Out:
# *
# *
# *

# %%
for i in range(5):
  print("*")
# Out:
# *
# *
# *
# *
# *

# %%
Name="Deepa"
print(Name)
# Out:
# Deepa
