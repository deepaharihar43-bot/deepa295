# %%
pip install pandas

# %%
import pandas as pd
(pd.__version__)
# Out:
# '2.2.3'

# %%
# series
import pandas as Deepa
Renuka=Deepa.Series([1,2,3,4,5])
Renuka
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
import pandas as pd
marks=pd.Series([85,90,75,95])
print(marks)
# Out:
# 0    85
# 1    90
# 2    75
# 3    95
# dtype: int64

# %% [markdown]
# pandas_series_numpy.py

# %%
import pandas as pd
arr=([10,20,30,40])
s=pd.Series(arr)
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd
arr=([10,20,30,40])
s=pd.Series(arr)
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# pandas_series_dicr.py

# %%
import pandas as pd
student={'Rahul':85,
         'Anita':92,
         'John':78}
s=pd.Series(student)
s
# Out:
# Rahul    85
# Anita    92
# John     78
# dtype: int64

# %% [markdown]
# pandas_series_tuple.py

# %%
import pandas as pd
arr=((10,20,30,40))
s=pd.Series(arr)
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# pandas_lseries_list.py

# %%
import pandas as pd
arr=([10,20,30,40,50])
s=pd.Series(arr)
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# dict to pandas series

# %%
import pandas as pd
Student={'Name':"deepa",
         'Reg_No':295,
         'College':"KLE",
         'Year':2026}
student
demo=pd.Series(Student)
demo
print(demo[1])
print(demo['College'])
print(demo[-2])
# Out:
# 295
# KLE
# KLE
# /tmp/ipykernel_2523/2854893462.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(demo[1])
# /tmp/ipykernel_2523/2854893462.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(demo[-2])

# %%
import pandas as pd
arr=[86,45,89,34,67,88,94,12]
data=pd.Series(arr)
data
print(data[data>82])
# Out:
# 0    86
# 2    89
# 5    88
# 6    94
# dtype: int64

# %%
import numpy as np
import pandas as py
arr=[80,90,100]
arr
marks=pd.Series(arr)
print(marks*2)
print([marks > 85])
print(marks[marks>80])
print(marks.dtype)
print(marks.shape)
print(marks.size)
print(marks.index)
print(marks.values)
# Out:
# 0    160
# 1    180
# 2    200
# dtype: int64
# [0    False
# 1     True
# 2     True
# dtype: bool]
# 1     90
# 2    100
# dtype: int64
# int64
# (3,)
# 3
# RangeIndex(start=0, stop=3, step=1)
# [ 80  90 100]

# %%
# 2) csv file to DataFrame
import pandas as pd
data = pd.read_csv("/content/Emp.csv")
data
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_2523/1807327980.py in <cell line: 0>()
#       1 # 2) csv file to DataFrame
#       2 import pandas as pd
# ----> 3 data = pd.read_csv("/content/Emp.csv")
#       4 data
#
# ...

# %% [markdown]
# Dataframe Programs

# %%
 # 1) Dict to Dataframe
 import pandas as pd
 demo={'Reg_No':[11,12,13,14,15,16],
        'Name':["Deepa","Renuka","Vijju","Sanjana","Uma","Mallamma"],
        'Age':[34,29,26,30,27,19],
        'Place':["Yalishirur","Hallikeri","Neregall","Haripur","Harti","Shirahatti"]
       }
 print(demo)
 data=pd.DataFrame(demo)
 print(data)
# Out:
# {'Reg_No': [11, 12, 13, 14, 15, 16], 'Name': ['Deepa', 'Renuka', 'Vijju', 'Sanjana', 'Uma', 'Mallamma'], 'Age': [34, 29, 26, 30, 27, 19], 'Place': ['Yalishirur', 'Hallikeri', 'Neregall', 'Haripur', 'Harti', 'Shirahatti']}
#    Reg_No      Name  Age       Place
# 0      11     Deepa   34  Yalishirur
# 1      12    Renuka   29   Hallikeri
# 2      13     Vijju   26    Neregall
# 3      14   Sanjana   30     Haripur
# 4      15       Uma   27       Harti
# 5      16  Mallamma   19  Shirahatti
